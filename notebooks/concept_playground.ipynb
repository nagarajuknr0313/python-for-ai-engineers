# %% [markdown]
# # Concept Playground
#
# This notebook lets you run the lesson concepts interactively in the browser. Start with the basics and then try the later topics.

# %%
# Example 1: variables and types
model_name = 'nebula-vision'
model_version = 3
is_multimodal = True
print(model_name)
print(model_version)
print(is_multimodal)

# %%
# Example 2: lists and loops
prompts = ['invoice', 'refund', 'policy']
processed = []
for prompt in prompts:
    processed.append(f'processed:{prompt}')
print(processed)

# %%
# Example 3: simple function

def build_prompt(task: str, tone: str) -> str:
    return f'Task: {task}\nTone: {tone}\nResponse: concise'

print(build_prompt('support', 'urgent'))
