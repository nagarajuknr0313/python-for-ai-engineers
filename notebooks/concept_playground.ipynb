# %% [markdown]
# # Concept Playground
#
# This notebook lets you run the lesson concepts interactively in the browser.

# %%
# Example: variables and types
model_name = 'nebula-vision'
print(model_name)
